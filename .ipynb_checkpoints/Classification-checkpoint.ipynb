# %% [markdown]
# #### Install all required libraries
# The following code was running on MacBook Pro 2020 with no Nvidia GPU

# %%
# !pip install numpy
# !pip uninstall tensorflow
# !pip install opencv-python
# !pip install matplotlib
# # !pip install --upgrade --index-url https://pypi.ngc.nvidia.com nvidia-tensorrt
# !pip install onnxruntime
# !pip install git+https://github.com/onnx/tensorflow-onnx
# Out:
# Requirement already satisfied: numpy in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.9/site-packages (1.24.0)
# Found existing installation: tensorflow 2.11.0
# Uninstalling tensorflow-2.11.0:
#   Would remove:
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/estimator_ckpt_converter
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/import_pb_to_tensorboard
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/saved_model_cli
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/tensorboard
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/tf_upgrade_v2
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/tflite_convert
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/toco
#     /Users/seyedalicheraghi/miniconda3/envs/tf/bin/toco_from_protos
#     /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow-2.11.0.dist-info/*
#     /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %% [markdown]
# #### Check list of installed packages

# %%
#!pip list

# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2
import imghdr

# %% [markdown]
# #### Check data

# %%
data_dir = "./data"
image_exts = ['jpg', 'jpeg', 'bmp', 'png']

# %%
wick = os.listdir(os.path.join(data_dir, 'wick'))
rambo = os.listdir(os.path.join(data_dir, 'rambo'))

# %% [markdown]
# #### The following Cell detect images with wrong extentions. These images could make problems during training the network.
#
# There is a file created by Mac called .DS_Store. Next cell will check each file and ignore it whenever it sees it.

# %%
# Go to the data directory
for image_class in os.listdir(data_dir): 
    if image_class == '.DS_Store':
        continue
    # Enter images directories
    for image in os.listdir(os.path.join(data_dir, image_class)):
        if image == '.DS_Store':
            continue
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %% [markdown]
# #### Next step is to load data for training

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
# Out:
# Found 127 files belonging to 2 classes.

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# #### Scale and Split Data

# %%
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()
train_size = int(len(data)*.6)
val_size = int(len(data)*.3)
test_size = int(len(data)*.1)
print("Train size", train_size)
print("Validation", val_size)
print("Test size", test_size)
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)
# Out:
# Train size 2
# Validation 1
# Test size 0

# %% [markdown]
# #### Build deep learning model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2/2 [==============================] - 5s 2s/step - loss: 0.6931 - accuracy: 0.5312 - val_loss: 0.6868 - val_accuracy: 0.6562
# Epoch 2/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6911 - accuracy: 0.5469 - val_loss: 0.7005 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.7069 - accuracy: 0.5000 - val_loss: 0.6736 - val_accuracy: 0.6250
# Epoch 4/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.7049 - accuracy: 0.4531 - val_loss: 0.6936 - val_accuracy: 0.4688
# Epoch 5/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.6940 - accuracy: 0.5312 - val_loss: 0.6934 - val_accuracy: 0.4375
# Epoch 6/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6930 - accuracy: 0.5156 - val_loss: 0.6927 - val_accuracy: 0.5625
# Epoch 7/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6930 - accuracy: 0.5312 - val_loss: 0.6927 - val_accuracy: 0.5625
# Epoch 8/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6927 - accuracy: 0.5625 - val_loss: 0.6929 - val_accuracy: 0.5312
# Epoch 9/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6934 - accuracy: 0.4688 - val_loss: 0.6926 - val_accuracy: 0.5625
# Epoch 10/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6925 - accuracy: 0.5625 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 11/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6935 - accuracy: 0.4688 - val_loss: 0.6916 - val_accuracy: 0.6250
# Epoch 12/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6928 - accuracy: 0.5312 - val_loss: 0.6907 - val_accuracy: 0.6875
# Epoch 13/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6926 - accuracy: 0.5469 - val_loss: 0.6927 - val_accuracy: 0.5312
# Epoch 14/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6929 - accuracy: 0.5156 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6911 - accuracy: 0.6094 - val_loss: 0.6906 - val_accuracy: 0.6250
# Epoch 16/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6922 - accuracy: 0.5469 - val_loss: 0.6948 - val_accuracy: 0.4375
# Epoch 17/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6916 - accuracy: 0.5625 - val_loss: 0.6923 - val_accuracy: 0.5312
# Epoch 18/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6943 - val_accuracy: 0.4688
# Epoch 19/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.6928 - accuracy: 0.5156 - val_loss: 0.6887 - val_accuracy: 0.6250
# Epoch 20/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.6903 - accuracy: 0.5781 - val_loss: 0.6921 - val_accuracy: 0.5312

# %% [markdown]
# #### Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32)

# %% [markdown]
# #### Testing

# %%
img = cv2.imread('rambo.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
yhat
# Out:
# array([[0.5963795]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Wick')
else:
    print(f'Predicted class is Rambo')
# Out:
# Predicted class is Wick

# %% [markdown]
# #### Save the Model

# %%
import tensorrt as trt

trt.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 import tensorrt as trt
#       3 trt.__version__
#
# ModuleNotFoundError: No module named 'tensorrt'
