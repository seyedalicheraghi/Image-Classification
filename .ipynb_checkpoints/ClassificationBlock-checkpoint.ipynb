# %% [markdown]
# #### Install all required libraries
# The following code was running on MacBook Pro 2020 with no Nvidia GPU

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install opencv-python
# !pip install matplotlib
# !pip install --upgrade --index-url https://pypi.ngc.nvidia.com nvidia-tensorrt
# !pip install onnxruntime==1.12.0
# !pip install git+https://github.com/onnx/tensorflow-onnx
# !pip install keras2onnx
# Out:
# Requirement already satisfied: tensorflow in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: setuptools in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.24.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (0.29.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: libclang>=13.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (5.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: numpy in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (1.24.0)
# Requirement already satisfied: opencv-python in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from opencv-python) (1.24.0)
# Requirement already satisfied: matplotlib in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: numpy>=1.19 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.24.0)
# Requirement already satisfied: packaging>=20.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: onnxruntime==1.12.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (1.12.0)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (22.0)
# Requirement already satisfied: protobuf in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (3.19.6)
# Requirement already satisfied: numpy>=1.21.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (1.24.0)
# Requirement already satisfied: flatbuffers in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (2.0.7)
# Requirement already satisfied: sympy in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (1.11.1)
# Requirement already satisfied: coloredlogs in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxruntime==1.12.0) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime==1.12.0) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from sympy->onnxruntime==1.12.0) (1.2.1)
# Collecting git+https://github.com/onnx/tensorflow-onnx
#   Cloning https://github.com/onnx/tensorflow-onnx to /private/var/folders/cs/6rccns7n009gq9rhvtrk57_80000gn/T/pip-req-build-zu2ea8fk
#   Running command git clone -q https://github.com/onnx/tensorflow-onnx /private/var/folders/cs/6rccns7n009gq9rhvtrk57_80000gn/T/pip-req-build-zu2ea8fk
#   Resolved https://github.com/onnx/tensorflow-onnx to commit 434b4a76e9aed2abf39e08b3191aa04fa6174ee0
# Requirement already satisfied: numpy>=1.14.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tf2onnx==1.13.0) (1.24.0)
# Requirement already satisfied: onnx>=1.4.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tf2onnx==1.13.0) (1.13.0)
# Requirement already satisfied: requests in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tf2onnx==1.13.0) (2.27.1)
# Requirement already satisfied: six in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tf2onnx==1.13.0) (1.16.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from tf2onnx==1.13.0) (2.0.7)
# Collecting protobuf<4,>=3.20.2
#   Using cached protobuf-3.20.3-cp39-cp39-macosx_10_9_x86_64.whl (982 kB)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnx>=1.4.1->tf2onnx==1.13.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->tf2onnx==1.13.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->tf2onnx==1.13.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->tf2onnx==1.13.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->tf2onnx==1.13.0) (2.0.4)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3
# Requirement already satisfied: keras2onnx in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (1.7.0)
# Requirement already satisfied: requests in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (2.27.1)
# Requirement already satisfied: protobuf in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (3.20.3)
# Requirement already satisfied: fire in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (0.5.0)
# Requirement already satisfied: onnx in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (1.13.0)
# Requirement already satisfied: numpy in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (1.24.0)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from keras2onnx) (1.13.0)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnxconverter-common>=1.7.0->keras2onnx) (22.0)
# Requirement already satisfied: six in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from fire->keras2onnx) (1.16.0)
# Requirement already satisfied: termcolor in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from fire->keras2onnx) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from onnx->keras2onnx) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->keras2onnx) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->keras2onnx) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->keras2onnx) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages (from requests->keras2onnx) (2.0.4)

# %% [markdown]
# #### Check list of installed packages

# %%
# !pip list

# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2
import imghdr

# %% [markdown]
# #### Check data

# %%
data_dir = "./data"
image_exts = ['jpg', 'jpeg', 'bmp', 'png']

# %%
wick = os.listdir(os.path.join(data_dir, 'wick'))
rambo = os.listdir(os.path.join(data_dir, 'rambo'))

# %% [markdown]
# #### The following Cell detect images with wrong extentions. These images could make problems during training the network.
#
# There is a file created by Mac called .DS_Store. Next cell will check each file and ignore it whenever it sees it.

# %%
# Go to the data directory
for image_class in os.listdir(data_dir): 
    if image_class == '.DS_Store':
        continue
    # Enter images directories
    for image in os.listdir(os.path.join(data_dir, image_class)):
        if image == '.DS_Store':
            continue
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %% [markdown]
# #### Next step is to load data for training

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
# Out:
# Found 127 files belonging to 2 classes.

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# #### Scale and Split Data

# %%
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()
train_size = int(len(data)*.6)
val_size = int(len(data)*.3)
test_size = int(len(data)*.1)
print("Train size", train_size)
print("Validation", val_size)
print("Test size", test_size)
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)
# Out:
# WARNING:tensorflow:From /Users/seyedalicheraghi/miniconda3/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Train size 2
# Validation 1
# Test size 0

# %% [markdown]
# #### Build deep learning model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
# model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
# model.add(MaxPooling2D())
# model.add(Conv2D(32, (3,3), 1, activation='relu'))
# model.add(MaxPooling2D())
# model.add(Conv2D(16, (3,3), 1, activation='relu'))
# model.add(MaxPooling2D())
# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters, kernel_size = (3, 3)):
        super(ConvBlock, self).__init__()
        self.conv = Conv2D(num_filters, kernel_size)
        self.bn = BatchNormalization()
        self.relu = Activation("relu")
        self.pooling = MaxPool2D()
    def call(self, x, pool=True):
        X = self.conv(x)
        X = self.bn(X)
        X = self.relu(X)
        if pool:
            X = self.pooling(X)

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=200, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 2/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 3/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 4/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 5/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 6/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 7/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 8/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 9/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.7717e-04 - val_accuracy: 1.0000
# Epoch 10/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 11/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 12/200
# 2/2 [==============================] - 3s 2s/step - loss: 8.0369e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 13/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 14/200
# 2/2 [==============================] - 3s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.6740e-04 - val_accuracy: 1.0000
# Epoch 15/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.4656e-04 - accuracy: 1.0000 - val_loss: 4.4371e-04 - val_accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.1627e-04 - accuracy: 1.0000 - val_loss: 3.2385e-04 - val_accuracy: 1.0000
# Epoch 17/200
# 2/2 [==============================] - 3s 2s/step - loss: 6.6532e-04 - accuracy: 1.0000 - val_loss: 1.5731e-04 - val_accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 3s 2s/step - loss: 3
200
# 2/2 [==============================] - 3s 2s/step - loss: 7.1471e-05 - accuracy: 1.0000 - val_loss: 3.9929e-05 - val_accuracy: 1.0000
# Epoch 64/200
# 2/2 [==============================] - 3s 2s/step - loss: 6.4745e-05 - accuracy: 1.0000 - val_loss: 5.3441e-05 - val_accuracy: 1.0000
# Epoch 65/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.9103e-05 - accuracy: 1.0000 - val_loss: 1.1655e-04 - val_accuracy: 1.0000
# Epoch 66/200
# 2/2 [==============================] - 3s 2s/step - loss: 5.1933e-05 - accuracy: 1.0000 - val_loss: 3.4996e-05 - val_accuracy: 1.0000
# Epoch 67/200
# 2/2 [==============================] - 3s 2s/step - loss: 7.3426e-05 - accuracy: 1.0000 - val_loss: 5.6029e-05 - val_accuracy: 1.0000
# Epoch 68/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.3520e-05 - accuracy: 1.0000 - val_loss: 2.3719e-05 - val_accuracy: 1.0000
# Epoch 69/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.7132e-05 - accuracy: 1.0000 - val_loss: 2.3556e-05 - val_accuracy: 1.0000
# Epoch 70/200
# 2/2 [==============================] - 3s 2s/step - loss: 6.3164e-05 - accuracy: 1.0000 - val_loss: 2.9316e-05 - val_accuracy: 1.0000
# Epoch 71/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.2528e-05 - accuracy: 1.0000 - val_loss: 8.1315e-05 - val_accuracy: 1.0000
# Epoch 72/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.8080e-05 - accuracy: 1.0000 - val_loss: 9.3201e-05 - val_accuracy: 1.0000
# Epoch 73/200
# 2/2 [==============================] - 3s 2s/step - loss: 5.9528e-05 - accuracy: 1.0000 - val_loss: 3.6468e-05 - val_accuracy: 1.0000
# Epoch 74/200
# 2/2 [==============================] - 3s 2s/step - loss: 5.8689e-05 - accuracy: 1.0000 - val_loss: 3.7007e-05 - val_accuracy: 1.0000
# Epoch 75/200
# 2/2 [==============================] - 3s 2s/step - loss: 5.8060e-05 - accuracy: 1.0000 - val_loss: 4.6387e-05 - val_accuracy: 1.0000
# Epoch 76/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.1287e-05 - accuracy: 1.0000 - val_loss: 2.5961e-05 - val_accuracy: 1.0000
# Epoch 77/200
# 2/2 [==============================] - 3s 2s/step - loss: 6.1919e-05 - accuracy: 1.0000 - val_loss: 7.1449e-05 - val_accuracy: 1.0000
# Epoch 78/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.7855e-05 - accuracy: 1.0000 - val_loss: 2.8296e-05 - val_accuracy: 1.0000
# Epoch 79/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.8665e-05 - accuracy: 1.0000 - val_loss: 2.0039e-05 - val_accuracy: 1.0000
# Epoch 80/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6265e-05 - accuracy: 1.0000 - val_loss: 5.8604e-05 - val_accuracy: 1.0000
# Epoch 81/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.5177e-05 - accuracy: 1.0000 - val_loss: 3.0576e-05 - val_accuracy: 1.0000
# Epoch 82/200
# 2/2 [==============================] - 3s 2s/step - loss: 4.8907e-05 - accuracy: 1.0000 - val_loss: 5.8808e-05 - val_accuracy: 1.0000
# Epoch 83/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.9507e-05 - accuracy: 1.0000 - val_loss: 2.8777e-05 - val_accuracy: 1.0000
# Epoch 84/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.6968e-05 - accuracy: 1.0000 - val_loss: 3.3185e-05 - val_accuracy: 1.0000
# Epoch 85/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6130e-05 - accuracy: 1.0000 - val_loss: 3.7041e-05 - val_accuracy: 1.0000
# Epoch 86/200
# 2/2 [==============================] - 3s 2s/step - loss: 2
200
# 2/2 [==============================] - 3s 2s/step - loss: 3.4570e-05 - accuracy: 1.0000 - val_loss: 1.8828e-05 - val_accuracy: 1.0000
# Epoch 113/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.6288e-05 - accuracy: 1.0000 - val_loss: 1.9437e-05 - val_accuracy: 1.0000
# Epoch 114/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.7642e-05 - accuracy: 1.0000 - val_loss: 4.8997e-05 - val_accuracy: 1.0000
# Epoch 115/200
# 2/2 [==============================] - 3s 2s/step - loss: 3.0378e-05 - accuracy: 1.0000 - val_loss: 1.8860e-05 - val_accuracy: 1.0000
# Epoch 116/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.7556e-05 - accuracy: 1.0000 - val_loss: 2.2482e-05 - val_accuracy: 1.0000
# Epoch 117/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.7253e-05 - accuracy: 1.0000 - val_loss: 3.6298e-05 - val_accuracy: 1.0000
# Epoch 118/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6882e-05 - accuracy: 1.0000 - val_loss: 3.7775e-05 - val_accuracy: 1.0000
# Epoch 119/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.0336e-05 - accuracy: 1.0000 - val_loss: 9.1052e-06 - val_accuracy: 1.0000
# Epoch 120/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6488e-05 - accuracy: 1.0000 - val_loss: 2.0278e-05 - val_accuracy: 1.0000
# Epoch 121/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.3640e-05 - accuracy: 1.0000 - val_loss: 1.9845e-05 - val_accuracy: 1.0000
# Epoch 122/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.8042e-05 - accuracy: 1.0000 - val_loss: 3.6945e-05 - val_accuracy: 1.0000
# Epoch 123/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.8622e-05 - accuracy: 1.0000 - val_loss: 1.1017e-05 - val_accuracy: 1.0000
# Epoch 124/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.5578e-05 - accuracy: 1.0000 - val_loss: 2.7587e-05 - val_accuracy: 1.0000
# Epoch 125/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6907e-05 - accuracy: 1.0000 - val_loss: 1.5128e-05 - val_accuracy: 1.0000
# Epoch 126/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.8825e-05 - accuracy: 1.0000 - val_loss: 1.7354e-05 - val_accuracy: 1.0000
# Epoch 127/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.4916e-05 - accuracy: 1.0000 - val_loss: 8.7123e-06 - val_accuracy: 1.0000
# Epoch 128/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6363e-05 - accuracy: 1.0000 - val_loss: 2.2056e-05 - val_accuracy: 1.0000
# Epoch 129/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.4214e-05 - accuracy: 1.0000 - val_loss: 1.4188e-05 - val_accuracy: 1.0000
# Epoch 130/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.2318e-05 - accuracy: 1.0000 - val_loss: 1.4972e-05 - val_accuracy: 1.0000
# Epoch 131/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.7210e-05 - accuracy: 1.0000 - val_loss: 3.5104e-05 - val_accuracy: 1.0000
# Epoch 132/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.5915e-05 - accuracy: 1.0000 - val_loss: 1.9533e-05 - val_accuracy: 1.0000
# Epoch 133/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.3706e-05 - accuracy: 1.0000 - val_loss: 1.9684e-05 - val_accuracy: 1.0000
# Epoch 134/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.6485e-05 - accuracy: 1.0000 - val_loss: 1.7640e-05 - val_accuracy: 1.0000
# Epoch 135/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.3219e-05 - accuracy: 1.0000 - val_loss: 1.9196e-05 - val_accuracy: 1.0000
# Epoch 136/200
# 2/2 [==============================] - 3s 2s/step - loss: 2.5207e-05 - accuracy: 1.0000 - val_loss: 9.9948e-06 - val_accuracy: 1.0000
# Epoch 137/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.4614e-05 - accuracy: 1.0000 - val_loss: 8.9802e-06 - val_accuracy: 1.0000
# Epoch 138/200
# 2/2 [==============================] - 3s 2s/step - loss: 1
uracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 4s 2s/step - loss: 1.3331e-05 - accuracy: 1.0000 - val_loss: 1.8307e-05 - val_accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 4s 2s/step - loss: 1.3150e-05 - accuracy: 1.0000 - val_loss: 1.5084e-05 - val_accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 4s 2s/step - loss: 1.2336e-05 - accuracy: 1.0000 - val_loss: 1.9718e-05 - val_accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.3382e-05 - accuracy: 1.0000 - val_loss: 8.4796e-06 - val_accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.1151e-05 - accuracy: 1.0000 - val_loss: 1.7201e-05 - val_accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 3s 2s/step - loss: 1.0066e-05 - accuracy: 1.0000 - val_loss: 1.2925e-05 - val_accuracy: 1.0000

# %% [markdown]
# #### Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32)

# %% [markdown]
# #### Testing

# %%
img = cv2.imread('rambo.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
yhat
# Out:
# array([[0.32599586]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Wick')
else:
    print(f'Predicted class is Rambo')
# Out:
# Predicted class is Rambo

# %% [markdown]
# #### Save the Model

# %%
# import tensorrt as trt

# trt.__version__

# %%
# from tensorflow.keras.models import load_model
# model.save(os.path.join('models','imageclassifier.h5'))
# new_model = load_model('imageclassifier.h5')
# new_model.predict(np.expand_dims(resize/255, 0))

# Save model in the saved_model format
SAVED_MODEL_DIR="./models/native_saved_model/"
model.save(SAVED_MODEL_DIR)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/native_saved_model/assets
# INFO:tensorflow:Assets written to: ./models/native_saved_model/assets

# %%
# !python -m tf2onnx.convert --saved-model "./models/native_saved_model" --output model.onnx --opset 11 --verbose
# Out:
# 2022-12-23 20:53:38.131787: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/seyedalicheraghi/miniconda3/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-12-23 20:53:41,720 - WARNING - tf2onnx.tf_loader: '--tag' not specified for saved_model. Using --tag serve
# 2022-12-23 20:53:41,992 - INFO - tf2onnx.tf_loader: Signatures found in model: [serving_default].
# 2022-12-23 20:53:41,992 - WARNING - tf2onnx.tf_loader: '--signature_def' not specified, using first signature: serving_default
# 2022-12-23 20:53:41,992 - INFO - tf2onnx.tf_loader: Output names: ['dense_1']
# 2022-12-23 20:53:42,601 - INFO - tf2onnx: inputs: ['conv2d_input:0']
# 2022-12-23 20:53:42,601 - INFO - tf2onnx: outputs: ['Identity:0']
# 2022-12-23 20:53:42,622 - INFO - tf2onnx.tfonnx: Using tensorflow=2.11.0, onnx=1.13.0, tf2onnx=1.13.0/434b4a
# 2022-12-23 20:53:42,622 - INFO - tf2onnx.tfonnx: Using opset <onnx, 11>
# 2022-12-23 20:53:42,747 - INFO - tf2onnx.tf_utils: Computed 0 values for constant folding
# 2022-12-23 20:53:42,840 - VERBOSE - tf2onnx.tfonnx: Mapping TF node to ONNX node(s)
# 2022-12-23 20:53:42,849 - VERBOSE - tf2onnx.tfonnx: Summay Stats:
# 	tensorflow ops: Counter({'Const': 11, 'BiasAdd': 5, 'Relu': 4, 'Conv2D': 3, 'MaxPool': 3, 'MatMul': 2, 'Identity': 2, 'Placeholder': 1, 'Reshape': 1, 'Sigmoid': 1})
# 	tensorflow attr: Counter({'dtype': 12, 'value': 11, 'data_format': 11, 'explicit_paddings': 6, 'padding': 6, 'strides': 6, 'dilations': 3, 'ksize': 3, 'transpose_a': 2, 'transpose_b': 2, 'shape': 1})
# 	onnx mapped: Counter({'Const': 11, 'Relu': 4, 'Conv2D': 3, 'MaxPool': 3, 'MatMul': 2, 'BiasAdd': 2, 'Placeholder': 1, 'Reshape': 1, 'Sigmoid': 1, 'Identity': 1})
# 	onnx unmapped: Counter()
# 2022-12-23 20:53:42,849 - INFO - tf2onnx.optimizer: Optimizing ONNX model
# 2022-12-23 20:53:42,849 - VERBOSE - tf2onnx.optimizer: Apply optimize_transpose
# 2022-12-23 20:53:42,862 - VERBOSE - tf2onnx.optimizer.TransposeOptimizer: Transpose -10 (12->2)
# 2022-12-23 20:53:42,862 - VERBOSE - tf2onnx.optimizer: Apply remove_redundant_upsample
# 2022-12-23 20:53:42,874 - VERBOSE - tf2onnx.optimizer.UpsampleOptimizer: no change
# 2022-12-23 20:53:42,874 - VERBOSE - tf2onnx.optimizer: Apply fold_constants
# 2022-12-23 20:53:42,887 - VERBOSE - tf2onnx.optimizer.ConstFoldOptimizer: Cast -1 (1->0)
# 2022-12-23 20:53:42,887 - VERBOSE - tf2onnx.optimizer: Apply const_dequantize_optimizer
# 2022-12-23 20:53:42,899 - VERBOSE - tf2onnx.optimizer.ConstDequantizeOptimizer: no change
# 2022-12-23 20:53:42,899 - VERBOSE - tf2onnx.optimizer: Apply loop_optimizer
# 2022-12-23 20:53:42,908 - VERBOSE - tf2onnx.optimizer.LoopOptimizer: no change
# 2022-12-23 20:53:42,908 - VERBOSE - tf2onnx.optimizer: Apply merge_duplication
# 2022-12-23 20:53:42,951 - VERBOSE - tf2onnx.optimizer.MergeDuplicatedNodesOptimizer: no change
# 2022-12-23 20:53:42,951 - VERBOSE - tf2onnx.optimizer: Apply reshape_optimizer
# 2022-12-23 20:53:42,967 - VERBOSE - tf2onnx.optimizer.ReshapeOptimizer: no change
# 2022-12-23 20:53:42,967 - VERBOSE - tf2onnx.optimizer: Apply global_pool_optimizer
# 2022-12-23 20:53:42,989 - VERBOSE - tf2onnx.optimizer.GlobalPoolOptimizer: no change
# 2022-12-23 20:53:42,990 - VERBOSE - tf2onnx.optimizer: Apply q_dq_optimizer
# 2022-12-23 20:53:43,012 - VERBOSE - tf2onnx.optimizer.QDQOptimizer: no change
# 2022-12-23 20:53:43,012 - VERBOSE - tf2onnx.optimizer: Apply remove_identity
# 2022-12-23 20:53:43,035 - VERBOSE - tf2onnx.optimizer.IdentityOptimizer: Identity -2 (2->0)
# 2022-12-23 20:53:43,035 - VERBOSE - tf2onnx.optimizer: Apply remove_back_to_back
# 2022-12-23 20:53:43,057 - VERBOSE - tf2onnx.optimizer.BackToBackOptimizer: no change
# 2022-12-23 20:53:43,057 - VERBOSE - tf2onnx.optimizer: Apply einsum_optimizer
# 2022-12-23 20:53:43,079 - VERBOSE - tf2onnx.optimizer.EinsumOptimizer: no change
# 2022-12-23 20:53:43,079 - VERBOSE - tf2onnx.optimizer: Apply optimize_transpose
# 2022-12-23 20:53:43,103 - VERBOSE - tf2onnx.optimizer.TransposeOptimizer: no change
# 2022-12-23 20:53:43,103 - VERBOSE - tf2onnx.optimizer: Apply remove_redundant_upsample
# 2022-12-23 20:53:43,127 - VERBOSE - tf2onnx.optimizer.UpsampleOptimizer: no change
# 2022-12-23 20:53:43,127 - VERBOSE - tf2onnx.optimizer: Apply fold_constants
# 2022-12-23 20:53:43,151 - VERBOSE - tf2onnx.optimizer.ConstFoldOptimizer: no change
# 2022-12-23 20:53:43,151 - VERBOSE - tf2onnx.optimizer: Apply const_dequantize_optimizer
# 2022-12-23 20:53:43,175 - VERBOSE - tf2onnx.optimizer.ConstDequantizeOptimizer: no change
# 2022-12-23 20:53:43,175 - VERBOSE - tf2onnx.optimizer: Apply loop_optimizer
# 2022-12-23 20:53:43,253 - VERBOSE - tf2onnx.optimizer.LoopOptimizer: no change
# 2022-12-23 20:53:43,253 - VERBOSE - tf2onnx.optimizer: Apply merge_duplication
# 2022-12-23 20:53:43,276 - VERBOSE - tf2onnx.optimizer.MergeDuplicatedNodesOptimizer: no change
# 2022-12-23 20:53:43,276 - VERBOSE - tf2onnx.optimizer: Apply reshape_optimizer
# 2022-12-23 20:53:43,287 - VERBOSE - tf2onnx.optimizer.ReshapeOptimizer: no change
# 2022-12-23 20:53:43,287 - VERBOSE - tf2onnx.optimizer: Apply global_pool_optimizer
# 2022-12-23 20:53:43,298 - VERBOSE - tf2onnx.optimizer.GlobalPoolOptimizer: no change
# 2022-12-23 20:53:43,298 - VERBOSE - tf2onnx.optimizer: Apply q_dq_optimizer
# 2022-12-23 20:53:43,310 - VERBOSE - tf2onnx.optimizer.QDQOptimizer: no change
# 2022-12-23 20:53:43,310 - VERBOSE - tf2onnx.optimizer: Apply remove_identity
# 2022-12-23 20:53:43,322 - VERBOSE - tf2onnx.optimizer.IdentityOptimizer: no change
# 2022-12-23 20:53:43,322 - VERBOSE - tf2onnx.optimizer: Apply remove_back_to_back
# 2022-12-23 20:53:43,333 - VERBOSE - tf2onnx.optimizer.BackToBackOptimizer: no change
# 2022-12-23 20:53:43,333 - VERBOSE - tf2onnx.optimizer: Apply einsum_optimizer
# 2022-12-23 20:53:43,343 - VERBOSE - tf2onnx.optimizer.EinsumOptimizer: no change
# 2022-12-23 20:53:43,343 - INFO - tf2onnx.optimizer: After optimization: Cast -1 (1->0), Identity -2 (2->0), Transpose -10 (12->2)
# 2022-12-23 20:53:43,374 - INFO - tf2onnx:
# 2022-12-23 20:53:43,374 - INFO - tf2onnx: Successfully converted TensorFlow model ./models/native_saved_model to ONNX
# 2022-12-23 20:53:43,375 - INFO - tf2onnx: Model inputs: ['conv2d_input']
# 2022-12-23 20:53:43,375 - INFO - tf2onnx: Model outputs: ['dense_1']
# 2022-12-23 20:53:43,375 - INFO - tf2onnx: ONNX model is saved at model.onnx
