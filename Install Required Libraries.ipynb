# %% [markdown]
# #### Install all required libraries
# The following code was running on MacBook Pro 2020 with no Nvidia GPU

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install opencv-python
# !pip install matplotlib
# !pip install --upgrade --index-url https://pypi.ngc.nvidia.com nvidia-tensorrt
# !pip install onnxruntime==1.12.0
# !pip install git+https://github.com/onnx/tensorflow-onnx
# !pip install keras2onnx
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-macosx_10_14_x86_64.whl (244.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 MB 3.6 MB/s eta 0:00:0000:0100:01
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp37-cp37m-macosx_10_10_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 7.0 MB/s eta 0:00:0000:0100:01m
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp37-cp37m-macosx_10_9_x86_64.whl (34 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp37-cp37m-macosx_10_9_x86_64.whl (979 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-macosx_10_9_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.0 MB/s eta 0:00:0000:0100:01m
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: six>=1.12.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorflow) (1.16.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorflow) (4.4.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.29.0-cp37-cp37m-macosx_10_14_x86_64.whl (1.6 MB)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorflow) (22.0)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: setuptools in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorflow) (65.5.0)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (5.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.11.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-22.12.6 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.7.0 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.29.0 termcolor-2.1.1 werkzeug-2.2.2 wrapt-1.14.1
# Requirement already satisfied: numpy in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (1.21.6)
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl (46.4 MB)
# Requirement already satisfied: numpy>=1.14.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Requirement already satisfied: matplotlib in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (3.5.3)
# Requirement already satisfied: packaging>=20.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: typing-extensions in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.4.0)
# Requirement already satisfied: six>=1.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting onnxruntime==1.12.0
#   Downloading onnxruntime-1.12.0-cp37-cp37m-macosx_10_15_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 6.9 MB/s eta 0:00:0000:0100:01
# Collecting sympy
#   Using cached sympy-1.10.1-py3-none-any.whl (6.4 MB)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnxruntime==1.12.0) (1.21.6)
# Requirement already satisfied: protobuf in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnxruntime==1.12.0) (3.19.6)
# Requirement already satisfied: flatbuffers in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnxruntime==1.12.0) (22.12.6)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnxruntime==1.12.0) (22.0)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.2.1-py3-none-any.whl (532 kB)
# Installing collected packages: mpmath, sympy, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 mpmath-1.2.1 onnxruntime-1.12.0 sympy-1.10.1
# Collecting git+https://github.com/onnx/tensorflow-onnx
#   Cloning https://github.com/onnx/tensorflow-onnx to /private/var/folders/cs/6rccns7n009gq9rhvtrk57_80000gn/T/pip-req-build-a3vn3p8p
#   Running command git clone --filter=blob:none --quiet https://github.com/onnx/tensorflow-onnx /private/var/folders/cs/6rccns7n009gq9rhvtrk57_80000gn/T/pip-req-build-a3vn3p8p
#   Resolved https://github.com/onnx/tensorflow-onnx to commit 434b4a76e9aed2abf39e08b3191aa04fa6174ee0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tf2onnx==1.13.0) (1.21.6)
# Collecting onnx>=1.4.1
#   Using cached onnx-1.13.0-cp37-cp37m-macosx_10_12_x86_64.whl (12.7 MB)
# Requirement already satisfied: requests in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tf2onnx==1.13.0) (2.28.1)
# Requirement already satisfied: six in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from tf2onnx==1.13.0) (1.16.0)
# Collecting flatbuffers<3.0,>=1.12
#   Using cached flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Collecting protobuf<4,>=3.20.2
#   Using cached protobuf-3.20.3-cp37-cp37m-macosx_10_9_x86_64.whl (981 kB)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnx>=1.4.1->tf2onnx==1.13.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->tf2onnx==1.13.0) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->tf2onnx==1.13.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->tf2onnx==1.13.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->tf2onnx==1.13.0) (3.4)
# Building wheels for collected packages: tf2onnx
#   Building wheel for tf2onnx (setup.py) ... done
#   Created wheel for tf2onnx: filename=tf2onnx-1.13.0-py3-none-any.whl size=442283 sha256=417f210fb8071964a9f75e601b452c43706fecf2b404d82409b657f8a8f394f2
#   Stored in directory: /private/var/folders/cs/6rccns7n009gq9rhvtrk57_80000gn/T/pip-ephem-wheel-cache-__ljt66l/wheels/73/99/8e/3034c9b47124da4ac24a6ea72b8da1be5af878e37c2e953bb3
# Successfully built tf2onnx
# Installing collected packages: flatbuffers, protobuf, onnx, tf2onnx
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 22.12.6
#     Uninstalling flatbuffers-22.12.6:
#       Successfully uninstalled flatbuffers-22.12.6
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed flatbuffers-2.0.7 onnx-1.13.0 protobuf-3.20.3 tf2onnx-1.13.0
# Collecting keras2onnx
#   Using cached keras2onnx-1.7.0-py3-none-any.whl (96 kB)
# Requirement already satisfied: protobuf in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from keras2onnx) (3.20.3)
# Requirement already satisfied: requests in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from keras2onnx) (2.28.1)
# Collecting fire
#   Using cached fire-0.5.0.tar.gz (88 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from keras2onnx) (1.21.6)
# Collecting onnxconverter-common>=1.7.0
#   Using cached onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
# Requirement already satisfied: onnx in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from keras2onnx) (1.13.0)
# Requirement already satisfied: packaging in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnxconverter-common>=1.7.0->keras2onnx) (22.0)
# Requirement already satisfied: six in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from fire->keras2onnx) (1.16.0)
# Requirement already satisfied: termcolor in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from fire->keras2onnx) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from onnx->keras2onnx) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->keras2onnx) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->keras2onnx) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->keras2onnx) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seyedalicheraghi/miniconda3/envs/tf/lib/python3.7/site-packages (from requests->keras2onnx) (1.26.13)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=ba32618784ce1eafcf70712a69258dd2632e2c9dc060a1c72695c334b0262f1b
#   Stored in directory: /Users/seyedalicheraghi/Library/Caches/pip/wheels/20/e8/7b/003fc14f02f262dd4614aec55e41147c8012e3dad98c936b76
# Successfully built fire
# Installing collected packages: fire, onnxconverter-common, keras2onnx
# Successfully installed fire-0.5.0 keras2onnx-1.7.0 onnxconverter-common-1.13.0

# %% [markdown]
# #### Check list of installed packages

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.3.0
# anyio                        3.6.2
# appnope                      0.1.3
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# astunparse                   1.6.3
# attrs                        22.2.0
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.1
# cachetools                   5.2.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# coloredlogs                  15.0.1
# cycler                       0.11.0
# debugpy                      1.6.4
# decorator                    5.1.1
# defusedxml                   0.7.1
# entrypoints                  0.4
# fastjsonschema               2.16.2
# fire                         0.5.0
# flatbuffers                  2.0.7
# fonttools                    4.38.0
# gast                         0.4.0
# google-auth                  2.15.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.51.1
# h5py                         3.7.0
# humanfriendly                10.0
# idna                         3.4
# importlib-metadata           5.2.0
# importlib-resources          5.10.1
# ipykernel                    6.16.2
# ipython                      7.34.0
# ipython-genutils             0.2.0
# ipywidgets                   8.0.4
# jedi                         0.18.2
# Jinja2                       3.1.2
# json5                        0.9.10
# jsonschema                   4.17.3
# jupyter                      1.0.0
# jupyter_client               7.4.8
# jupyter-console              6.4.4
# jupyter_core                 4.12.0
# jupyter-server               1.23.4
# jupyterlab                   3.5.2
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.16.6
# jupyterlab-widgets           3.0.5
# keras                        2.11.0
# keras2onnx                   1.7.0
# kiwisolver                   1.4.4
# lab                          7.2
# libclang                     14.0.6
# Markdown                     3.4.1
# MarkupSafe                   2.1.1
# matplotlib                   3.5.3
# matplotlib-inline            0.1.6
# mistune                      2.0.4
# mpmath                       1.2.1
# nbclassic                    0.4.8
# nbclient                     0.7.2
# nbconvert                    7.2.7
# nbformat                     5.7.1
# nest-asyncio                 1.5.6
# notebook                     6.5.2
# notebook_shim                0.2.2
# numpy                        1.21.6
# oauthlib                     3.2.2
# onnx                         1.13.0
# onnxconverter-common         1.13.0
# onnxruntime                  1.12.0
# opencv-python                4.6.0.66
# opt-einsum                   3.3.0
# packaging                    22.0
# pandocfilters                1.5.0
# parso                        0.8.3
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.3.0
# pip                          22.3.1
# pkgutil_resolve_name         1.3.10
# prometheus-client            0.15.0
# prompt-toolkit               3.0.36
# protobuf                     3.20.3
# psutil                       5.9.4
# ptyprocess                   0.7.0
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycparser                    2.21
# Pygments                     2.13.0
# pyparsing                    3.0.9
# pyrsistent                   0.19.2
# python-dateutil              2.8.2
# pytz                         2022.7
# pyzmq                        24.0.1
# qtconsole                    5.4.0
# QtPy                         2.3.0
# requests                     2.28.1
# requests-oauthlib            1.3.1
# rsa                          4.9
# Send2Trash                   1.8.0
# setuptools                   65.5.0
# simplejson                   3.18.0
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.3.2.post1
# sympy                        1.10.1
# tensorboard                  2.11.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.11.0
# tensorflow-estimator         2.11.0
# tensorflow-io-gcs-filesystem 0.29.0
# termcolor                    2.1.1
# terminado                    0.17.1
# tf2onnx                      1.13.0
# tinycss2                     1.2.1
# tomli                        2.0.1
# tornado                      6.2
# traitlets                    5.8.0
# txt2tags                     3.7
# typing_extensions            4.4.0
# urllib3                      1.26.13
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             1.4.2
# Werkzeug                     2.2.2
# wheel                        0.37.1
# widgetsnbextension           4.0.5
# wrapt                        1.14.1
# zipp                         3.11.0
